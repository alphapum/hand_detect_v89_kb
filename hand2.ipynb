# %%
# !pip install HandDetector

# %% [markdown]
# ## Error bug count max 8

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Convert the image color space
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the image with MediaPipe
        results = hands.process(image)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Extract finger landmarks
                finger_landmarks = [hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]]

                # Check if the fingers are extended
                extended_fingers = [1 if finger_landmark.y < finger_landmarks[0].y else 0
                                    for finger_landmark in finger_landmarks[1:]]

                # Count the extended fingers
                finger_count += sum(extended_fingers)

                # Draw landmarks on the image
                mp_hands.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

 

        # Draw finger count on the image
        cv2.putText(image, f"Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting image
        cv2.imshow('Finger Count', cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Error bug count max 4

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    # max_num_hands=2,
    min_detection_confidence=0.2,
    min_tracking_confidence=0.2) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Convert the image color space
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the image with MediaPipe
        results = hands.process(image)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Extract finger landmarks
                finger_landmarks = [hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]]

                # Check if the fingers are extended
                extended_fingers = [1 if finger_landmark.y < finger_landmarks[0].y else 0
                                    for finger_landmark in finger_landmarks[1:]]

                # Count the extended fingers
                finger_count += sum(extended_fingers)

                # Draw landmarks on the image
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

        # Draw finger count on the image
        cv2.putText(image, f"Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting image
        cv2.imshow('Finger Count', cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Error bug count max 4

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.1,
    min_tracking_confidence=0.1) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Convert the image color space
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the image with MediaPipe
        results = hands.process(image)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Extract finger landmarks
                finger_landmarks = [hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]]

                # Check if the fingers are extended
                extended_fingers = [1 if finger_landmark.y < finger_landmarks[0].y else 0
                                    for finger_landmark in finger_landmarks]

                # Count the extended fingers
                finger_count += sum(extended_fingers)

                # Draw landmarks on the image
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

        # Draw finger count on the image
        cv2.putText(image, f"Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting image
        cv2.imshow('Finger Count', cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Error bug count max 8 only

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    # max_num_hands=2,
    min_detection_confidence=0.1,
    min_tracking_confidence=0.1) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Convert the image color space
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the image with MediaPipe
        results = hands.process(image)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Extract finger landmarks
                finger_landmarks = [hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]]

                # Check if the fingers are extended
                extended_fingers = [1 if finger_landmark.y < finger_landmarks[0].y else 0
                                    for finger_landmark in finger_landmarks]

                # Count the extended fingers
                finger_count += sum(extended_fingers)

                # Draw landmarks on the image
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

        # Draw finger count on the image
        cv2.putText(image, f"Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting image
        cv2.imshow('Finger Count', cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Error bug count max 10 only

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Convert the image color space
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the image with MediaPipe
        results = hands.process(image)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Extract finger landmarks
                finger_landmarks = [hand_landmarks.landmark[mp_hands.HandLandmark.WRIST],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]]

                # Check if the fingers are extended
                extended_fingers = [1 if finger_landmark.y < finger_landmarks[0].y else 0
                                    for finger_landmark in finger_landmarks[1:]]

                # Count the extended fingers
                finger_count += sum(extended_fingers)

                # Draw landmarks on the image
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

        # Draw finger count on the image
        cv2.putText(image, f"Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting image
        cv2.imshow('Finger Count', cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Error bug count max 17

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Convert the image color space
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the image with MediaPipe
        results = hands.process(image)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Extract finger landmarks
                finger_landmarks = [hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_CMC],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_MCP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_IP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_PIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_DIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_PIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_DIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_PIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_DIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_PIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_DIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]]

                # Check the state of each finger
                finger_states = [1 if finger_landmark.x < 0.5 else 0 for finger_landmark in finger_landmarks]

                # Count the open fingers
                finger_count += sum(finger_states)

                # Draw landmarks on the image
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

        # Draw finger count on the image
        cv2.putText(image, f"Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting image
        cv2.imshow('Finger Count', cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Convert the image color space
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the image with MediaPipe
        results = hands.process(image)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Initialize the finger count for the current hand
                hand_finger_count = 0

                # Extract finger landmarks
                for finger_id in range(1, 5):
                    finger_tip = hand_landmarks.landmark[mp_hands.HandLandmark(finger_id).TIP]
                    finger_dip = hand_landmarks.landmark[mp_hands.HandLandmark(finger_id).DIP]
                    finger_pip = hand_landmarks.landmark[mp_hands.HandLandmark(finger_id).PIP]
                    finger_mcp = hand_landmarks.landmark[mp_hands.HandLandmark(finger_id).MCP]

                    # Check the state of the finger
                    if finger_tip.y < finger_dip.y and finger_dip.y < finger_pip.y and finger_pip.y < finger_mcp.y:
                        hand_finger_count += 1

                # Add the finger count of the current hand to the overall finger count
                finger_count += hand_finger_count

                # Draw landmarks on the image
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

                # Draw finger count on the image for the current hand
                cv2.putText(image, f"Hand Finger Count: {hand_finger_count}", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.8,
                            (0, 0, 255), 2)

        # Draw overall finger count on the image
        cv2.putText(image, f"Total Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting image
        cv2.imshow('Finger Count', cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Convert the image color space
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the image with MediaPipe
        results = hands.process(image)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Initialize the finger count for the current hand
                hand_finger_count = 0

                # Extract finger landmarks
                finger_landmarks = [hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP],
                                    hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]]

                # Check the state of each finger
                for finger_landmark in finger_landmarks:
                    if finger_landmark.y < finger_landmarks[0].y:
                        hand_finger_count += 1

                # Add the finger count of the current hand to the overall finger count
                finger_count += hand_finger_count

                # Draw landmarks on the image
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

                # Draw finger count on the image for the current hand
                cv2.putText(image, f"Hand Finger Count: {hand_finger_count}", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.8,
                            (0, 0, 255), 2)

        # Draw overall finger count on the image
        cv2.putText(image, f"Total Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting image
        cv2.imshow('Finger Count', cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Convert the image color space to gray
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Convert the grayscale image back to BGR for rendering colored landmarks
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

        # Process the image with MediaPipe
        results = hands.process(image)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Initialize the finger count for the current hand
                hand_finger_count = 0

                # Check if all the required landmarks are present
                if (mp_hands.HandLandmark.THUMB_TIP in hand_landmarks.landmark and
                    mp_hands.HandLandmark.INDEX_FINGER_TIP in hand_landmarks.landmark and
                    mp_hands.HandLandmark.MIDDLE_FINGER_TIP in hand_landmarks.landmark and
                    mp_hands.HandLandmark.RING_FINGER_TIP in hand_landmarks.landmark and
                    mp_hands.HandLandmark.PINKY_TIP in hand_landmarks.landmark):

                    # Extract finger landmarks
                    finger_landmarks = [hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP],
                                        hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP],
                                        hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP],
                                        hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP],
                                        hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP]]

                    # Check the state of each finger
                    for finger_landmark in finger_landmarks:
                        if finger_landmark.y < finger_landmarks[0].y:
                            hand_finger_count += 1

                    # Add the finger count of the current hand to the overall finger count
                    finger_count += hand_finger_count

                    # Draw landmarks on the image with gray color
                    mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS,
                                              mp_drawing.DrawingSpec(color=(128, 128, 128)),
                                              mp_drawing.DrawingSpec(color=(128, 128, 128)))

                    # Draw finger count on the image for the current hand with gray color
                    cv2.putText(image, f"Hand Finger Count: {hand_finger_count}", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.8,
                                (128, 128, 128), 2)

        # Draw overall finger count on the image with gray color
        cv2.putText(image, f"Total Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8,
                    (128, 128, 128), 2)

        # Display the resulting image
        cv2.imshow('Finger Count', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Convert the image color space to gray
        # gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # # Process the image with MediaPipe
        # results = hands.process(frame)

        # Convert the grayscale image back to BGR for rendering
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the image with MediaPipe
        results = hands.process(image)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Convert hand landmarks to numpy array
                landmark_array = mp_hands._normalized_landmark_list(hand_landmarks, image.shape[1], image.shape[0])

                # Extract the hand contour from landmarks
                contour = landmark_array[:, :2].reshape((-1, 1, 2)).astype(int)

                # Apply convex hull to the hand contour
                hull = cv2.convexHull(contour)

                # Calculate the defects in the convex hull
                hull_with_defects = cv2.convexityDefects(contour, cv2.convexHull(contour, returnPoints=False))

                # Count the fingers based on defects
                if hull_with_defects is not None:
                    for i in range(hull_with_defects.shape[0]):
                        start, end, _, _ = hull_with_defects[i, 0]
                        start_point = tuple(contour[start, 0])
                        end_point = tuple(contour[end, 0])
                        far_point = tuple(contour[hull_with_defects[i, 0, 2], 0])

                        # Calculate the distances between points
                        start_end_dist = cv2.norm(start_point, end_point)
                        start_far_dist = cv2.norm(start_point, far_point)
                        end_far_dist = cv2.norm(end_point, far_point)

                        # Check if the defects represent a finger
                        if start_end_dist > 100 and start_far_dist / start_end_dist > 0.25 and end_far_dist / start_end_dist > 0.25:
                            finger_count += 1

                # Draw landmarks and hand contour on the image
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
                cv2.drawContours(image, [hull], 0, (0, 255, 0), 2)

        # Draw finger count on the image
        cv2.putText(image, f"Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting image
        cv2.imshow('Finger Count', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import numpy as np

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Process the frame with MediaPipe
        results = hands.process(frame)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Extract the hand landmarks
                landmark_list = []
                for landmark in hand_landmarks.landmark:
                    # Convert normalized coordinates to pixel values
                    x, y, z = int(landmark.x * frame.shape[1]), int(landmark.y * frame.shape[0]), landmark.z
                    landmark_list.append([x, y, z])

                # Convert the landmark list to a NumPy array
                landmark_array = np.array(landmark_list, dtype=np.float32)

                # Convert the array to the shape expected by convexHull
                contour = landmark_array[:, :2].reshape((-1, 2)).astype(np.int32)

                # Apply convex hull to the hand contour
                hull = cv2.convexHull(contour)

                # Calculate the defects in the convex hull
                hull_with_defects = cv2.convexityDefects(contour, cv2.convexHull(contour, returnPoints=False))

                # Count the fingers based on defects
                if hull_with_defects is not None:
                    for i in range(hull_with_defects.shape[0]):
                        start, end, _, _ = hull_with_defects[i, 0]
                        start_point = tuple(contour[start])
                        end_point = tuple(contour[end])
                        far_point = tuple(contour[hull_with_defects[i, 0, 2]])

                        # Calculate the distances between points
                        start_end_dist = cv2.norm(start_point, end_point)
                        start_far_dist = cv2.norm(start_point, far_point)
                        end_far_dist = cv2.norm(end_point, far_point)

                        # Check if the defects represent a finger
                        if start_end_dist > 100 and start_far_dist / start_end_dist > 0.25 and end_far_dist / start_end_dist > 0.25:
                            finger_count += 1

                # Draw landmarks and hand contour on the frame
                mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
                cv2.drawContours(frame, [hull], 0, (0, 255, 0), 2)

        # Draw finger count on the frame
        cv2.putText(frame, f"Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting frame
        cv2.imshow('Finger Count', frame)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 57
#      54 far_point = tuple(contour[hull_with_defects[i, 0, 2]])
#      56 # Calculate the distances between points
# ---> 57 start_end_dist = cv2.norm(start_point, end_point)
#      58 start_far_dist = cv2.norm(start_point, far_point)
#      59 end_far_dist = cv2.norm(end_point, far_point)
#
# error: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'norm'
# > Overload resolution failed:
# >  - src1 is not a numerical tuple
# >  - Expected Ptr<cv::UMat> for argument 'src1'
# >  - src1 is not a numerical tuple
# >  - Expected Ptr<cv::UMat> for argument 'src1'

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:

    while cap.isOpened():
        ret, frame = cap.read()

        # Process the frame with MediaPipe
        results = hands.process(frame)

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Count the fingers based on hand landmarks
                finger_count = len(hand_landmarks.landmark) - 1  # Subtract 1 for the wrist landmark

                # Draw hand landmarks on the frame
                mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

        # Draw finger count on the frame
        cv2.putText(frame, f"Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting frame
        cv2.imshow('Finger Count', frame)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## This max = 10 but fix error thumnell Goode
#
# Thump TIP < MCP (5)

# %%
import cv2
import mediapipe as mp

# MediaPipe hand detection module
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# OpenCV video capture
cap = cv2.VideoCapture(0)

# Create a hands object
with mp_hands.Hands(
    static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5) as hands:

    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.flip(frame, 1)

        # Process the frame with MediaPipe
        results = hands.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

        # Count the number of fingers
        finger_count = 0
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                # Calculate the finger count
                if   hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP].y < hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP].y:
                    finger_count += 1
                if hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].y < hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_PIP].y:
                    finger_count += 1
                if hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP].y < hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_PIP].y:
                    finger_count += 1
                if hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP].y < hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_PIP].y:
                    finger_count += 1
                if hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP].y < hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_PIP].y:
                    finger_count += 1

                # Draw hand landmarks on the frame
                mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

        # Draw finger count on the frame
        cv2.putText(frame, f"Finger Count: {finger_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Display the resulting frame
        cv2.imshow('Finger Count', frame)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
